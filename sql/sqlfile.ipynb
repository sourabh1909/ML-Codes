# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib.parse

# Load CSV
df = pd.read_csv("flights_cleaned.csv")

# Rename column (important)
df.rename(columns={"index": "id"}, inplace=True)

# Fix password
password = urllib.parse.quote_plus("sourabh")

# Connect to your DB (IMPORTANT: your DB name is 'flights')
engine = create_engine(
    f"mysql+pymysql://root:{password}@localhost:3300/flights"
)

# Insert data
df.to_sql(
    name="flights",
    con=engine,
    if_exists="append",   # 🔥 IMPORTANT (don't use replace now)
    index=False
)

print("Data inserted successfully ✅")
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[2], line 20
#      15 engine = create_engine(
#      16     f"mysql+pymysql://root:{password}@localhost:3300/flights"
#      17 )
#      19 # Insert data
# ---> 20 df.to_sql(
#      21     name="flights",
#      22     con=engine,
#      23     if_exists="append",   # 🔥 IMPORTANT (don't use replace now)
#      24     index=False
#      25 )
#      27 print("Data inserted successfully ✅")
#
# File f:\Data_Science\envs\booksenv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# ...

# %%
import mysql.connector
print("executed")
# Out:
# executed
