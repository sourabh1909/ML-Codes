# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ft = pd.read_csv('flights_cleaned.csv')

# %%
ft
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0            Jet Airways      2019-01-03  Banglore   New Delhi
# 1               SpiceJet      2019-01-03  Banglore   New Delhi
# 2            Jet Airways      2019-01-03  Banglore   New Delhi
# 3              Air India      2019-01-03  Banglore   New Delhi
# 4            Jet Airways      2019-01-03  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 10678  Multiple carriers      2019-12-06     Delhi      Cochin
# 10679             IndiGo      2019-12-06   Kolkata    Banglore
# 10680        Jet Airways      2019-12-06     Delhi      Cochin
# 10681           Air Asia      2019-12-06   Kolkata    Banglore
# 10682        Jet Airways      2019-12-06     Delhi      Cochin
#
#                        Route Dep_Time  Duration Total_Stops  Price
# 0            BLR → BOM → DEL    11:40       785      1 stop  26890
# 1            BLR → HYD → DEL    15:35       485      1 stop   7744
# ...

# %%
ft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Duration         10683 non-null  int64
#  7   Total_Stops      10682 non-null  object
#  8   Price            10683 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 751.3+ KB

# %%
ft[ft['Route'].isna()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  Duration  \
# 6451  Air India      2019-06-05  Delhi      Cochin   NaN    09:45      1420
#
#      Total_Stops  Price
# 6451         NaN   7480

# %%
ft['Route']=ft['Route'].fillna('DEL → BOM → COK	')

# %%
ft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10683 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Duration         10683 non-null  int64
#  7   Total_Stops      10682 non-null  object
#  8   Price            10683 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 751.3+ KB

# %%
ft
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0            Jet Airways      2019-01-03  Banglore   New Delhi
# 1               SpiceJet      2019-01-03  Banglore   New Delhi
# 2            Jet Airways      2019-01-03  Banglore   New Delhi
# 3              Air India      2019-01-03  Banglore   New Delhi
# 4            Jet Airways      2019-01-03  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 10678  Multiple carriers      2019-12-06     Delhi      Cochin
# 10679             IndiGo      2019-12-06   Kolkata    Banglore
# 10680        Jet Airways      2019-12-06     Delhi      Cochin
# 10681           Air Asia      2019-12-06   Kolkata    Banglore
# 10682        Jet Airways      2019-12-06     Delhi      Cochin
#
#                        Route Dep_Time  Duration Total_Stops  Price
# 0            BLR → BOM → DEL    11:40       785      1 stop  26890
# 1            BLR → HYD → DEL    15:35       485      1 stop   7744
# ...

# %%
ft[[ft['Source'] == 'Chennai'][ft['Destination'] == 'Delhi']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 ft[[ft['Source'] == 'Chennai'][ft['Destination'] == 'Delhi']]
#
# TypeError: list indices must be integers or slices, not Series

# %%
ft[(ft['Source'] == 'Mumbai')]
# Out:
#            Airline Date_of_Journey  Source Destination      Route Dep_Time  \
# 14          IndiGo      2019-01-03  Mumbai   Hyderabad  BOM → HYD    16:55
# 26       Air India      2019-01-03  Mumbai   Hyderabad  BOM → HYD    13:55
# 95          IndiGo      2019-01-03  Mumbai   Hyderabad  BOM → HYD    02:30
# 120    Jet Airways      2019-01-03  Mumbai   Hyderabad  BOM → HYD    07:10
# 125         IndiGo      2019-01-03  Mumbai   Hyderabad  BOM → HYD    06:20
# ...            ...             ...     ...         ...        ...      ...
# 10530    Air India      2019-12-06  Mumbai   Hyderabad  BOM → HYD    13:55
# 10599    Air India      2019-12-06  Mumbai   Hyderabad  BOM → HYD    21:05
# 10635    Air India      2019-12-06  Mumbai   Hyderabad  BOM → HYD    19:30
# 10636  Jet Airways      2019-12-06  Mumbai   Hyderabad  BOM → HYD    07:05
# 10660       IndiGo      2019-12-06  Mumbai   Hyderabad  BOM → HYD    21:20
#
#        Duration Total_Stops  Price
# ...

# %%
# ft[ft['Source'] == 'Delhi'].head()
ft[ft['Source'] == 'Mumbai'].head()
# ft[ft['Source'] == 'Kolkata'].head()
# ft[ft['Source'] == 'Hyderabad'].head()
# ft[ft['Source'] == 'Cochin'].head()
# ft[ft['Source'] == 'Chennai'].head()
# # ft[ft['Source'] == 'New Delhi'].head()
# ft[ft['Source'] == 'Banglore'].head()
# Out:
#          Airline Date_of_Journey  Source Destination      Route Dep_Time  \
# 14        IndiGo      2019-01-03  Mumbai   Hyderabad  BOM → HYD    16:55
# 26     Air India      2019-01-03  Mumbai   Hyderabad  BOM → HYD    13:55
# 95        IndiGo      2019-01-03  Mumbai   Hyderabad  BOM → HYD    02:30
# 120  Jet Airways      2019-01-03  Mumbai   Hyderabad  BOM → HYD    07:10
# 125       IndiGo      2019-01-03  Mumbai   Hyderabad  BOM → HYD    06:20
#
#      Duration Total_Stops  Price
# 14         90    non-stop   8853
# 26         90    non-stop  10082
# 95         90    non-stop  16000
# 120        85    non-stop  17501
# 125        85    non-stop  17501
