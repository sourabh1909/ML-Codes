# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Here we have to classify whether given fruit is orange or apple by sklearn decision tree.
# fruits can classify on weight and color

# %%
features = [
    [150,0], #apple
    [170,0], #apple
    [130,1], #orange
    [120,1] #orange
]

labels = ['apple','apple','orange','orange']

# %%
clf = DecisionTreeClassifier()

# %%
clf =clf.fit(features,labels)

# %%
clf.predict([[150,1]])
# Out:
# array(['orange'], dtype='<U6')

# %%
clf.predict([[135,0]])
# Out:
# array(['apple'], dtype='<U6')

# %%
prediction = clf.predict([[180,0]])

# %%
print(f'The fruit is {prediction[0]}')
# Out:
# The fruit is apple

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
plot_tree
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plot_tree
#
# NameError: name 'plot_tree' is not defined

# %%
plt.figure(figsize=(11,6))

# %%
plot_tree(clf,feature_names=['weight','color'],class_names=['apple','orange'],filled=True)
# Out:
# [Text(0.5, 0.75, 'color <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = apple'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = apple'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = orange'),
#  Text(0.625, 0.5, '  False')]
