# %% [markdown]
# ### Numerical PipeLine

# %% [markdown]
# - As dataset grow more complex, data preprocessing ofter involves multiple steps such as imputing missing values, scaling feature, encoding variables etc. These must be applied in the correct order and categorical varible training, validation,test and future production data.

# %% [markdown]
# A typically pipeline for numrical attributes might include
# 1. Imputing of missing values (e.g with median)
# 2. Feature scaling (e.g with standardization)
