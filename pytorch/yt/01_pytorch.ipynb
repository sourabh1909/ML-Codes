# %%
import torch
print(torch.__version__)
# Out:
# 2.7.0

# %%
if torch.cuda.is_available():
    print("CUDA is available. You can use GPU.")
else:
    print("CUDA is not available. Using CPU.")
# Out:
# CUDA is not available. Using CPU.

# %%
torch.ones(3,2)
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])

# %%
s = torch.rand(2,3)*10

# %%
torch.manual_seed(100)  # used to get same output of randome function
torch.rand(2,3)
# Out:
# tensor([[0.1117, 0.8158, 0.2626],
#         [0.4839, 0.6765, 0.7539]])

# %%
torch.manual_seed(100)
s =torch.rand(2,3)

# %%
torch.tensor([[1,2,3],[5,6,7]])
# Out:
# tensor([[1, 2, 3],
#         [5, 6, 7]])

# %%
# same functions like numpy 
# linspace
# arange
# torch.eye, identity matrix

# ((Shape),element)
torch.full((3,3),5)
# Out:
# tensor([[5, 5, 5],
#         [5, 5, 5],
#         [5, 5, 5]])

# %%
torch.ones(3,3)*5
# Out:
# tensor([[5., 5., 5.],
#         [5., 5., 5.],
#         [5., 5., 5.]])

# %% [markdown]
# Shape Tensor

# %%
x = torch.tensor([[1,2,30],[8,5,9]])
x.shape
# Out:
# torch.Size([2, 3])

# %%
torch.empty_like(x) 
# to copy the shape of another matrix0
# Out:
# tensor([[0, 0, 0],
#         [0, 0, 0]])

# %%
torch.ones_like(x)
# Out:
# tensor([[1, 1, 1],
#         [1, 1, 1]])

# %%
torch.rand_like(x,dtype=torch.float32)
# Out:
# tensor([[0.2627, 0.0428, 0.2080],
#         [0.1180, 0.1217, 0.7356]])

# %%
torch.tensor([1.,2.,3.],dtype=torch.int64)
# Out:
# tensor([1, 2, 3])

# %%
# mathematical operations
# we can apply tensor + scaler
x +2
# Out:
# tensor([[ 3,  4, 32],
#         [10,  7, 11]])

# %%
a = torch.linspace(-10,10,11)

# %%
a + 2
# Out:
# tensor([-8., -6., -4., -2.,  0.,  2.,  4.,  6.,  8., 10., 12.])

# %%
torch.abs(a)
# Out:
# tensor([10.,  8.,  6.,  4.,  2.,  0.,  2.,  4.,  6.,  8., 10.])

# %%
torch.round(s)
# rounding up the number
# Out:
# tensor([[0., 1., 0.],
#         [0., 1., 1.]])

# %%
torch.floor(s)
# give behind integer value
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
torch.ceil(s)
# give forword integer value
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
# clamp
torch.clamp(a,min=4,max=10)
# Out:
# tensor([ 4.,  4.,  4.,  4.,  4.,  4.,  4.,  4.,  6.,  8., 10.])
