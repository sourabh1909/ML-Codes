# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
latlong = pd.read_csv('district wise centroids.csv')
latlong.shape
# Out:
# (594, 4)

# %%
# find is there is any null
latlong.isnull().sum()
# Out:
# State        0
# District     0
# Latitude     0
# Longitude    0
# dtype: int64

# %%
# is duplicate
latlong[latlong.duplicated()]
# Out:
# Empty DataFrame
# Columns: [State, District, Latitude, Longitude]
# Index: []

# %%
census = pd.read_csv('india-districts-census-2011.csv')

# %%
latlong.head()
# Out:
#                  State         District   Latitude  Longitude
# 0  Andaman and Nicobar  Andaman Islands  12.382571  92.822911
# 1  Andaman and Nicobar  Nicobar Islands   7.835291  93.511601
# 2       Andhra Pradesh         Adilabad  19.284514  78.813212
# 3       Andhra Pradesh        Anantapur  14.312066  77.460158
# 4       Andhra Pradesh         Chittoor  13.331093  78.927639

# %%
census.head(2)
# Out:
#    District code         State name District name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
#
#    Literate  Male_Literate  Female_Literate    SC  ...  \
# 0    439654         282823           156831  1048  ...
# 1    335649         207741           127908   368  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                            94                           588
# 1                           126                           562
#
#    Power_Parity_Rs_150000_240000  Power_Parity_Rs_240000_330000  \
# 0                             71                            101
# 1                             72                             89
#
#    Power_Parity_Rs_150000_330000  Power_Parity_Rs_330000_425000  \
# 0                            172                             74
# ...

# %%
col =['District code','District name','Population','Male','Female','Literate','Households_with_Internet']

# %%
census=census[col]

# %%
census.rename(columns={'District name':'District'},inplace=True)

# %%
final_df = latlong.merge(census,on='District')

# %%
final_df['Sex Ratio']= (final_df['Female'] / final_df['Male'])*1000

# %%
final_df
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#      Population     Male   Female  Literate  Households_with_Internet  \
# ...

# %%
final_df['literacy_rate'] = (final_df['Literate'] / final_df['Population'])*100

# %%
final_df
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#      Population     Male   Female  Literate  Households_with_Internet  \
# ...

# %%
final_df.drop(columns=['Male','Female','Literate'],inplace=True)

# %%
final_df.to_csv('india.csv',index=False)

# %%
list_of_state = list(final_df['State'].unique())

# %%
list_of_state.insert(0,'Overall India')

# %%
list_of_state
# Out:
# ['Overall India',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Daman and Diu',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Orissa',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttaranchal',
#  'West Bengal']

# %%
sorted(final_df.columns[5:])
# Out:
# ['Households_with_Internet', 'Population', 'Sex Ratio', 'literacy_rate']

# %%
import plotly.express as px
df = px.data.carshare
fig = px.scatter_mapbox(final_df,lat='Latitude',lon='Longitude'
                          ,zoom=3,mapbox_style='carto-positron')
fig.show()
# Out:
# C:\Users\soura\AppData\Local\Temp\ipykernel_16224\3704454017.py:3: DeprecationWarning:
#
# *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
