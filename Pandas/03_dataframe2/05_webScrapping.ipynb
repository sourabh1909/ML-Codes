# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text
# this method is not accessable

header  = 
requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text
# Out:
# '<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;ambitionbox&#46;com&#47;list&#45;of&#45;companies&#63;" on this server.<P>\nReference&#32;&#35;18&#46;9df4df17&#46;1772535078&#46;ad360ef\n<P>https&#58;&#47;&#47;errors&#46;edgesuite&#46;net&#47;18&#46;9df4df17&#46;1772535078&#46;ad360ef</P>\n</BODY>\n</HTML>\n'
