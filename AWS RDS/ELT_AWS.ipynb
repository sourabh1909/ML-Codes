# %% [markdown]
# ETL ::
#     - Extract Transfer Load
#
# OLTP (Online Transaction Processing)::
#     - running database
#     - main database
#
# OLAP (Online Analytic Processing) ::
#     - copy of that main database
#     - analysis team working of this database
#
# Pipeline ::
#     - throught which your data is flowing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
